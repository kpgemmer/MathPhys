# %%
import matplotlib.pyplot as plt

# %%
beta = 0.00007
gamma = 0.004

# Startwerte
radikant = 10
schitt_nr  = [0]
a = [5]



for t in range(1,2000):
    schritt_nr.append(t)
    # ab hier muss etwas verändert werden...
    a.append(a[t-1] - 1)



# Daten in Diagramm schreiben
plt.plot(zeit, s, label="S")
plt.plot(zeit, i, label="I")
plt.plot(zeit, r, label="R")

# Achsenbeschriftungen erstellen
plt.xlabel('Zeit (d)')
plt.ylabel('Anzahl')

# Gitter und Legende erstellen lassen
plt.grid()
plt.legend()

# Diagramm erstellen
plt.show()
