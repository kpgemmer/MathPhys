# %%
from PIL import Image

# Load the image
img = Image.open("wg.jpg")
img = img.convert("RGB")
pixels = img.load()

# Show unmodified image
display(img)

# Loop over the pixels
for x in range(img.width):
    for y in range(img.height):
        r, g, b = pixels[x, y]
        # Calculate new Pixels
        pixels[x, y] = (0, b, 0)

display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=780x444>
# <PIL.Image.Image image mode=RGB size=780x444>
